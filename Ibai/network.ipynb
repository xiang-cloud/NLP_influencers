# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
from pyvis.network import Network
import numpy as np

# Load your CSV
df = pd.read_csv('refined_per_data.csv')

# filter weights <= 10 but save the list of inlfuencers
influencers = [
    'ibai',
    'auronplay',
    'marta díaz',
    'djmario',
    'clakovi',
    'elrubius',
    'emma chamberlain',
    'malbert',
    'mostopapi',
    'orslok',
    'vegetta'
]

df = df[(df['Weight'] > 120) | (df['Target'].isin(influencers))]


# Determine the 10th and 90th percentile weights
lower_bound = np.percentile(df['Weight'], 10)
upper_bound = np.percentile(df['Weight'], 90)

# Calculate cumulative weight for each target node
node_weights = df.groupby('Target')['Weight'].sum().to_dict()

# Normalize node sizes for visualization
min_node_size = 10
max_node_size = 50
node_sizes = {
    node: np.interp(weight, (min(node_weights.values()), max(node_weights.values())), (min_node_size, max_node_size))
    for node, weight in node_weights.items()
}

# Create a pyvis network
net = Network(notebook=True)

# Add nodes with sizes based on cumulative weights
for node in pd.concat([df['Source'], df['Target']]).unique():  # Ensure every unique node is added
    size = node_sizes.get(node, min_node_size)  # If a node doesn't have a cumulative weight, use the minimum size
    net.add_node(node, size=size)

# Add edges with widths based on individual weights
for index, row in df.iterrows():
    source = row['Source']
    target = row['Target']
    weight = row['Weight']
    
    # Normalize edge width
    width = np.interp(weight, (lower_bound, upper_bound), (0.5, 5))
    
    net.add_edge(source, target, width=width)

# Display the network
net.show("network.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# network.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="network.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import display

# Sort the dataframe by 'Weight' in descending order
sorted_df = df.sort_values(by='Weight', ascending=False)

# Use pandas styling to highlight the 'Weight' column with a gradient and display the top rows
display(sorted_df.head(30).style.background_gradient(cmap='Blues', subset=['Weight']))
# Out:
# <style type="text/css">
# #T_61bbe_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_61bbe_row1_col2 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_61bbe_row2_col2 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_61bbe_row3_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_61bbe_row4_col2 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_61bbe_row5_col2, #T_61bbe_row6_col2 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_61bbe_row7_col2, #T_61bbe_row8_col2 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_61bbe_row9_col2, #T_61bbe_row10_col2, #T_61bbe_row11_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_61bbe_row12_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_61bbe_row13_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_61bbe_row14_col2, #T_61bbe_row15_col2, #T_61bbe_row16_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_61bbe_row17_col2 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_61bbe_row18_col2, #T_61bbe_row19_col2, #T_61bbe_row20_col2 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_61bbe_row21_col2 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_61bbe_row22_col2, #T_61bbe_row23_col2, #T_61bbe_row24_col2, #T_61bbe_row25_col2 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_61bbe_row26_col2, #T_61bbe_row27_col2, #T_61bbe_row28_col2, #T_61bbe_row29_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_61bbe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61bbe_level0_col0" class="col_heading level0 col0" >Source</th>
#       <th id="T_61bbe_level0_col1" class="col_heading level0 col1" >Target</th>
#       <th id="T_61bbe_level0_col2" class="col_heading level0 col2" >Weight</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61bbe_level0_row0" class="row_heading level0 row0" >1360</th>
#       <td id="T_61bbe_row0_col0" class="data row0 col0" >YouTuber</td>
#       <td id="T_61bbe_row0_col1" class="data row0 col1" >ibai</td>
#       <td id="T_61bbe_row0_col2" class="data row0 col2" >4434</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row1" class="row_heading level0 row1" >1938</th>
#       <td id="T_61bbe_row1_col0" class="data row1 col0" >YouTuber</td>
#       <td id="T_61bbe_row1_col1" class="data row1 col1" >luzu</td>
#       <td id="T_61bbe_row1_col2" class="data row1 col2" >551</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row2" class="row_heading level0 row2" >1695</th>
#       <td id="T_61bbe_row2_col0" class="data row2 col0" >YouTuber</td>
#       <td id="T_61bbe_row2_col1" class="data row2 col1" >karchez</td>
#       <td id="T_61bbe_row2_col2" class="data row2 col2" >547</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row3" class="row_heading level0 row3" >153</th>
#       <td id="T_61bbe_row3_col0" class="data row3 col0" >YouTuber</td>
#       <td id="T_61bbe_row3_col1" class="data row3 col1" >ander</td>
#       <td id="T_61bbe_row3_col2" class="data row3 col2" >475</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row4" class="row_heading level0 row4" >2575</th>
#       <td id="T_61bbe_row4_col0" class="data row4 col0" >YouTuber</td>
#       <td id="T_61bbe_row4_col1" class="data row4 col1" >pol</td>
#       <td id="T_61bbe_row4_col2" class="data row4 col2" >441</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row5" class="row_heading level0 row5" >1765</th>
#       <td id="T_61bbe_row5_col0" class="data row5 col0" >YouTuber</td>
#       <td id="T_61bbe_row5_col1" class="data row5 col1" >komanche</td>
#       <td id="T_61bbe_row5_col2" class="data row5 col2" >387</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row6" class="row_heading level0 row6" >264</th>
#       <td id="T_61bbe_row6_col0" class="data row6 col0" >YouTuber</td>
#       <td id="T_61bbe_row6_col1" class="data row6 col1" >auronplay</td>
#       <td id="T_61bbe_row6_col2" class="data row6 col2" >385</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row7" class="row_heading level0 row7" >2718</th>
#       <td id="T_61bbe_row7_col0" class="data row7 col0" >YouTuber</td>
#       <td id="T_61bbe_row7_col1" class="data row7 col1" >reven</td>
#       <td id="T_61bbe_row7_col2" class="data row7 col2" >375</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row8" class="row_heading level0 row8" >536</th>
#       <td id="T_61bbe_row8_col0" class="data row8 col0" >YouTuber</td>
#       <td id="T_61bbe_row8_col1" class="data row8 col1" >carola</td>
#       <td id="T_61bbe_row8_col2" class="data row8 col2" >365</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row9" class="row_heading level0 row9" >1617</th>
#       <td id="T_61bbe_row9_col0" class="data row9 col0" >YouTuber</td>
#       <td id="T_61bbe_row9_col1" class="data row9 col1" >juan</td>
#       <td id="T_61bbe_row9_col2" class="data row9 col2" >332</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row10" class="row_heading level0 row10" >847</th>
#       <td id="T_61bbe_row10_col0" class="data row10 col0" >YouTuber</td>
#       <td id="T_61bbe_row10_col1" class="data row10 col1" >djmario</td>
#       <td id="T_61bbe_row10_col2" class="data row10 col2" >320</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row11" class="row_heading level0 row11" >134</th>
#       <td id="T_61bbe_row11_col0" class="data row11 col0" >YouTuber</td>
#       <td id="T_61bbe_row11_col1" class="data row11 col1" >ampeter</td>
#       <td id="T_61bbe_row11_col2" class="data row11 col2" >319</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row12" class="row_heading level0 row12" >2115</th>
#       <td id="T_61bbe_row12_col0" class="data row12 col0" >YouTuber</td>
#       <td id="T_61bbe_row12_col1" class="data row12 col1" >messi</td>
#       <td id="T_61bbe_row12_col2" class="data row12 col2" >269</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row13" class="row_heading level0 row13" >1266</th>
#       <td id="T_61bbe_row13_col0" class="data row13 col0" >YouTuber</td>
#       <td id="T_61bbe_row13_col1" class="data row13 col1" >gritan</td>
#       <td id="T_61bbe_row13_col2" class="data row13 col2" >236</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row14" class="row_heading level0 row14" >2627</th>
#       <td id="T_61bbe_row14_col0" class="data row14 col0" >YouTuber</td>
#       <td id="T_61bbe_row14_col1" class="data row14 col1" >quackity</td>
#       <td id="T_61bbe_row14_col2" class="data row14 col2" >222</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row15" class="row_heading level0 row15" >2759</th>
#       <td id="T_61bbe_row15_col0" class="data row15 col0" >YouTuber</td>
#       <td id="T_61bbe_row15_col1" class="data row15 col1" >rivers</td>
#       <td id="T_61bbe_row15_col2" class="data row15 col2" >215</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row16" class="row_heading level0 row16" >306</th>
#       <td id="T_61bbe_row16_col0" class="data row16 col0" >YouTuber</td>
#       <td id="T_61bbe_row16_col1" class="data row16 col1" >barbe</td>
#       <td id="T_61bbe_row16_col2" class="data row16 col2" >214</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row17" class="row_heading level0 row17" >2967</th>
#       <td id="T_61bbe_row17_col0" class="data row17 col0" >YouTuber</td>
#       <td id="T_61bbe_row17_col1" class="data row17 col1" >siro</td>
#       <td id="T_61bbe_row17_col2" class="data row17 col2" >208</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row18" class="row_heading level0 row18" >979</th>
#       <td id="T_61bbe_row18_col0" class="data row18 col0" >YouTuber</td>
#       <td id="T_61bbe_row18_col1" class="data row18 col1" >elrubius</td>
#       <td id="T_61bbe_row18_col2" class="data row18 col2" >193</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row19" class="row_heading level0 row19" >3002</th>
#       <td id="T_61bbe_row19_col0" class="data row19 col0" >YouTuber</td>
#       <td id="T_61bbe_row19_col1" class="data row19 col1" >spursito</td>
#       <td id="T_61bbe_row19_col2" class="data row19 col2" >189</td>
#     </tr>
#     <tr>
#       <th id="T_61bbe_level0_row20" class="row_hea

# %%
# Filter the DataFrame to only show rows corresponding to the influencers
filtered_df = df[df['Target'].isin(influencers)]

# Sort by weight in descending order
filtered_df = filtered_df.sort_values(by='Weight', ascending=False)

# Display the table
display(filtered_df.style.background_gradient(cmap='Blues', subset=['Weight']))
# Out:
# <style type="text/css">
# #T_d641e_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d641e_row1_col2 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_d641e_row2_col2 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_d641e_row3_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_d641e_row4_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_d641e_row5_col2, #T_d641e_row6_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_d641e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d641e_level0_col0" class="col_heading level0 col0" >Source</th>
#       <th id="T_d641e_level0_col1" class="col_heading level0 col1" >Target</th>
#       <th id="T_d641e_level0_col2" class="col_heading level0 col2" >Weight</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d641e_level0_row0" class="row_heading level0 row0" >1360</th>
#       <td id="T_d641e_row0_col0" class="data row0 col0" >YouTuber</td>
#       <td id="T_d641e_row0_col1" class="data row0 col1" >ibai</td>
#       <td id="T_d641e_row0_col2" class="data row0 col2" >4434</td>
#     </tr>
#     <tr>
#       <th id="T_d641e_level0_row1" class="row_heading level0 row1" >264</th>
#       <td id="T_d641e_row1_col0" class="data row1 col0" >YouTuber</td>
#       <td id="T_d641e_row1_col1" class="data row1 col1" >auronplay</td>
#       <td id="T_d641e_row1_col2" class="data row1 col2" >385</td>
#     </tr>
#     <tr>
#       <th id="T_d641e_level0_row2" class="row_heading level0 row2" >847</th>
#       <td id="T_d641e_row2_col0" class="data row2 col0" >YouTuber</td>
#       <td id="T_d641e_row2_col1" class="data row2 col1" >djmario</td>
#       <td id="T_d641e_row2_col2" class="data row2 col2" >320</td>
#     </tr>
#     <tr>
#       <th id="T_d641e_level0_row3" class="row_heading level0 row3" >979</th>
#       <td id="T_d641e_row3_col0" class="data row3 col0" >YouTuber</td>
#       <td id="T_d641e_row3_col1" class="data row3 col1" >elrubius</td>
#       <td id="T_d641e_row3_col2" class="data row3 col2" >193</td>
#     </tr>
#     <tr>
#       <th id="T_d641e_level0_row4" class="row_heading level0 row4" >3193</th>
#       <td id="T_d641e_row4_col0" class="data row4 col0" >YouTuber</td>
#       <td id="T_d641e_row4_col1" class="data row4 col1" >vegetta</td>
#       <td id="T_d641e_row4_col2" class="data row4 col2" >89</td>
#     </tr>
#     <tr>
#       <th id="T_d641e_level0_row5" class="row_heading level0 row5" >2377</th>
#       <td id="T_d641e_row5_col0" class="data row5 col0" >YouTuber</td>
#       <td id="T_d641e_row5_col1" class="data row5 col1" >orslok</td>
#       <td id="T_d641e_row5_col2" class="data row5 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d641e_level0_row6" class="row_heading level0 row6" >2216</th>
#       <td id="T_d641e_row6_col0" class="data row6 col0" >YouTuber</td>
#       <td id="T_d641e_row6_col1" class="data row6 col1" >mostopapi</td>
#       <td id="T_d641e_row6_col2" class="data row6 col2" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Convert the 'Source' column to the first name of the 'Target' column
filtered_df['Source'] = filtered_df['Target'].iloc[0]

# Remove the first row
filtered_df = filtered_df.iloc[1:]

print(filtered_df)

# Export the new DataFrame to CSV
filtered_df.to_csv('PER_filtered_data.csv', index=False)
# Out:
#      Source     Target  Weight
# 264    ibai  auronplay     385
# 847    ibai    djmario     320
# 979    ibai   elrubius     193
# 3193   ibai    vegetta      89
# 2377   ibai     orslok       4
# 2216   ibai  mostopapi       2
