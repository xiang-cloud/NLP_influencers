# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
from pyvis.network import Network
import numpy as np

# Load your CSV
df = pd.read_csv('refined_per_data.csv')

# filter weights <= 10 but save the list of inlfuencers
influencers = [
    'ibai',
    'auronplay',
    'marta díaz',
    'djmario',
    'clakovi',
    'elrubius',
    'emma chamberlain',
    'malbert',
    'mostopapi',
    'orslok',
    'vegetta'
]

df = df[(df['Weight'] > 10) | (df['Target'].isin(influencers))]


# Determine the 10th and 90th percentile weights
lower_bound = np.percentile(df['Weight'], 10)
upper_bound = np.percentile(df['Weight'], 90)

# Calculate cumulative weight for each target node
node_weights = df.groupby('Target')['Weight'].sum().to_dict()

# Normalize node sizes for visualization
min_node_size = 10
max_node_size = 50
node_sizes = {
    node: np.interp(weight, (min(node_weights.values()), max(node_weights.values())), (min_node_size, max_node_size))
    for node, weight in node_weights.items()
}

# Create a pyvis network
net = Network(notebook=True)

# Add nodes with sizes based on cumulative weights
for node in pd.concat([df['Source'], df['Target']]).unique():  # Ensure every unique node is added
    size = node_sizes.get(node, min_node_size)  # If a node doesn't have a cumulative weight, use the minimum size
    net.add_node(node, size=size)

# Add edges with widths based on individual weights
for index, row in df.iterrows():
    source = row['Source']
    target = row['Target']
    weight = row['Weight']
    
    # Normalize edge width
    width = np.interp(weight, (lower_bound, upper_bound), (0.5, 5))
    
    net.add_edge(source, target, width=width)

# Display the network
net.show("network.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# network.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="network.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import display

# Sort the dataframe by 'Weight' in descending order
sorted_df = df.sort_values(by='Weight', ascending=False)

# Use pandas styling to highlight the 'Weight' column with a gradient and display the top rows
display(sorted_df.head(20).style.background_gradient(cmap='Blues', subset=['Weight']))
# Out:
# <style type="text/css">
# #T_7d2d0_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7d2d0_row1_col2 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_7d2d0_row2_col2 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_7d2d0_row3_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_7d2d0_row4_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_7d2d0_row5_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_7d2d0_row6_col2 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_7d2d0_row7_col2 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_7d2d0_row8_col2 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_7d2d0_row9_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_7d2d0_row10_col2 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_7d2d0_row11_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_7d2d0_row12_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_7d2d0_row13_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_7d2d0_row14_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_7d2d0_row15_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_7d2d0_row16_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_7d2d0_row17_col2, #T_7d2d0_row18_col2 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_7d2d0_row19_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_7d2d0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d2d0_level0_col0" class="col_heading level0 col0" >Source</th>
#       <th id="T_7d2d0_level0_col1" class="col_heading level0 col1" >Target</th>
#       <th id="T_7d2d0_level0_col2" class="col_heading level0 col2" >Weight</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d2d0_level0_row0" class="row_heading level0 row0" >948</th>
#       <td id="T_7d2d0_row0_col0" class="data row0 col0" >YouTuber</td>
#       <td id="T_7d2d0_row0_col1" class="data row0 col1" >juan</td>
#       <td id="T_7d2d0_row0_col2" class="data row0 col2" >562</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row1" class="row_heading level0 row1" >139</th>
#       <td id="T_7d2d0_row1_col0" class="data row1 col0" >YouTuber</td>
#       <td id="T_7d2d0_row1_col1" class="data row1 col1" >auronplay</td>
#       <td id="T_7d2d0_row1_col2" class="data row1 col2" >386</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row2" class="row_heading level0 row2" >534</th>
#       <td id="T_7d2d0_row2_col0" class="data row2 col0" >YouTuber</td>
#       <td id="T_7d2d0_row2_col1" class="data row2 col1" >draco</td>
#       <td id="T_7d2d0_row2_col2" class="data row2 col2" >242</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row3" class="row_heading level0 row3" >1397</th>
#       <td id="T_7d2d0_row3_col0" class="data row3 col0" >YouTuber</td>
#       <td id="T_7d2d0_row3_col1" class="data row3 col1" >paul</td>
#       <td id="T_7d2d0_row3_col2" class="data row3 col2" >183</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row4" class="row_heading level0 row4" >816</th>
#       <td id="T_7d2d0_row4_col0" class="data row4 col0" >YouTuber</td>
#       <td id="T_7d2d0_row4_col1" class="data row4 col1" >ibai</td>
#       <td id="T_7d2d0_row4_col2" class="data row4 col2" >142</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row5" class="row_heading level0 row5" >804</th>
#       <td id="T_7d2d0_row5_col0" class="data row5 col0" >YouTuber</td>
#       <td id="T_7d2d0_row5_col1" class="data row5 col1" >horacio</td>
#       <td id="T_7d2d0_row5_col2" class="data row5 col2" >133</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row6" class="row_heading level0 row6" >519</th>
#       <td id="T_7d2d0_row6_col0" class="data row6 col0" >YouTuber</td>
#       <td id="T_7d2d0_row6_col1" class="data row6 col1" >djmario</td>
#       <td id="T_7d2d0_row6_col2" class="data row6 col2" >130</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row7" class="row_heading level0 row7" >665</th>
#       <td id="T_7d2d0_row7_col0" class="data row7 col0" >YouTuber</td>
#       <td id="T_7d2d0_row7_col1" class="data row7 col1" >focus</td>
#       <td id="T_7d2d0_row7_col2" class="data row7 col2" >123</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row8" class="row_heading level0 row8" >308</th>
#       <td id="T_7d2d0_row8_col0" class="data row8 col0" >YouTuber</td>
#       <td id="T_7d2d0_row8_col1" class="data row8 col1" >carola</td>
#       <td id="T_7d2d0_row8_col2" class="data row8 col2" >121</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row9" class="row_heading level0 row9" >378</th>
#       <td id="T_7d2d0_row9_col0" class="data row9 col0" >YouTuber</td>
#       <td id="T_7d2d0_row9_col1" class="data row9 col1" >comanche</td>
#       <td id="T_7d2d0_row9_col2" class="data row9 col2" >103</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row10" class="row_heading level0 row10" >758</th>
#       <td id="T_7d2d0_row10_col0" class="data row10 col0" >YouTuber</td>
#       <td id="T_7d2d0_row10_col1" class="data row10 col1" >gustavo</td>
#       <td id="T_7d2d0_row10_col2" class="data row10 col2" >86</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row11" class="row_heading level0 row11" >1371</th>
#       <td id="T_7d2d0_row11_col0" class="data row11 col0" >YouTuber</td>
#       <td id="T_7d2d0_row11_col1" class="data row11 col1" >paco</td>
#       <td id="T_7d2d0_row11_col2" class="data row11 col2" >84</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row12" class="row_heading level0 row12" >873</th>
#       <td id="T_7d2d0_row12_col0" class="data row12 col0" >YouTuber</td>
#       <td id="T_7d2d0_row12_col1" class="data row12 col1" >javi</td>
#       <td id="T_7d2d0_row12_col2" class="data row12 col2" >65</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row13" class="row_heading level0 row13" >456</th>
#       <td id="T_7d2d0_row13_col0" class="data row13 col0" >YouTuber</td>
#       <td id="T_7d2d0_row13_col1" class="data row13 col1" >daniel</td>
#       <td id="T_7d2d0_row13_col2" class="data row13 col2" >64</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row14" class="row_heading level0 row14" >424</th>
#       <td id="T_7d2d0_row14_col0" class="data row14 col0" >YouTuber</td>
#       <td id="T_7d2d0_row14_col1" class="data row14 col1" >dale</td>
#       <td id="T_7d2d0_row14_col2" class="data row14 col2" >59</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row15" class="row_heading level0 row15" >590</th>
#       <td id="T_7d2d0_row15_col0" class="data row15 col0" >YouTuber</td>
#       <td id="T_7d2d0_row15_col1" class="data row15 col1" >emilio</td>
#       <td id="T_7d2d0_row15_col2" class="data row15 col2" >55</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row16" class="row_heading level0 row16" >118</th>
#       <td id="T_7d2d0_row16_col0" class="data row16 col0" >YouTuber</td>
#       <td id="T_7d2d0_row16_col1" class="data row16 col1" >aurelio</td>
#       <td id="T_7d2d0_row16_col2" class="data row16 col2" >54</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row17" class="row_heading level0 row17" >1847</th>
#       <td id="T_7d2d0_row17_col0" class="data row17 col0" >YouTuber</td>
#       <td id="T_7d2d0_row17_col1" class="data row17 col1" >violeta</td>
#       <td id="T_7d2d0_row17_col2" class="data row17 col2" >46</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row18" class="row_heading level0 row18" >1391</th>
#       <td id="T_7d2d0_row18_col0" class="data row18 col0" >YouTuber</td>
#       <td id="T_7d2d0_row18_col1" class="data row18 col1" >pato</td>
#       <td id="T_7d2d0_row18_col2" class="data row18 col2" >45</td>
#     </tr>
#     <tr>
#       <th id="T_7d2d0_level0_row19" class="row_heading level0 row19" >581</th>
#       <td id="T_7d2d0_row19_col0" class="data row19 col0" >YouTuber</td>
#       <td id="T_7d2d0_row19_col1" class="data row19 col1" >elrubius</td>
#       <td id="T_7d2d0_row19_col2" class="data row19 col2" >42</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Filter the DataFrame to only show rows corresponding to the influencers
filtered_df = df[df['Target'].isin(influencers)]

# Sort by weight in descending order
filtered_df = filtered_df.sort_values(by='Weight', ascending=False)

# Display the table
display(filtered_df.style.background_gradient(cmap='Blues', subset=['Weight']))
# Out:
# <style type="text/css">
# #T_06a56_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_06a56_row1_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_06a56_row2_col2 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_06a56_row3_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_06a56_row4_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_06a56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06a56_level0_col0" class="col_heading level0 col0" >Source</th>
#       <th id="T_06a56_level0_col1" class="col_heading level0 col1" >Target</th>
#       <th id="T_06a56_level0_col2" class="col_heading level0 col2" >Weight</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06a56_level0_row0" class="row_heading level0 row0" >139</th>
#       <td id="T_06a56_row0_col0" class="data row0 col0" >YouTuber</td>
#       <td id="T_06a56_row0_col1" class="data row0 col1" >auronplay</td>
#       <td id="T_06a56_row0_col2" class="data row0 col2" >386</td>
#     </tr>
#     <tr>
#       <th id="T_06a56_level0_row1" class="row_heading level0 row1" >816</th>
#       <td id="T_06a56_row1_col0" class="data row1 col0" >YouTuber</td>
#       <td id="T_06a56_row1_col1" class="data row1 col1" >ibai</td>
#       <td id="T_06a56_row1_col2" class="data row1 col2" >142</td>
#     </tr>
#     <tr>
#       <th id="T_06a56_level0_row2" class="row_heading level0 row2" >519</th>
#       <td id="T_06a56_row2_col0" class="data row2 col0" >YouTuber</td>
#       <td id="T_06a56_row2_col1" class="data row2 col1" >djmario</td>
#       <td id="T_06a56_row2_col2" class="data row2 col2" >130</td>
#     </tr>
#     <tr>
#       <th id="T_06a56_level0_row3" class="row_heading level0 row3" >581</th>
#       <td id="T_06a56_row3_col0" class="data row3 col0" >YouTuber</td>
#       <td id="T_06a56_row3_col1" class="data row3 col1" >elrubius</td>
#       <td id="T_06a56_row3_col2" class="data row3 col2" >42</td>
#     </tr>
#     <tr>
#       <th id="T_06a56_level0_row4" class="row_heading level0 row4" >1827</th>
#       <td id="T_06a56_row4_col0" class="data row4 col0" >YouTuber</td>
#       <td id="T_06a56_row4_col1" class="data row4 col1" >vegetta</td>
#       <td id="T_06a56_row4_col2" class="data row4 col2" >27</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Convert the 'Source' column to the first name of the 'Target' column
filtered_df['Source'] = filtered_df['Target'].iloc[0]

# Remove the first row
filtered_df = filtered_df.iloc[1:]

print(filtered_df)

# Export the new DataFrame to CSV
filtered_df.to_csv('PER_filtered_data.csv', index=False)
# Out:
#          Source    Target  Weight
# 816   auronplay      ibai     142
# 519   auronplay   djmario     130
# 581   auronplay  elrubius      42
# 1827  auronplay   vegetta      27
